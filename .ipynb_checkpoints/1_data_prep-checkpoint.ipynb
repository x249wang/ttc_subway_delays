# %% [markdown]
# # TTC Subway Delay Analysis
# ## Data Prep

# %% [markdown]
# ### Get Data from City of Toronto Open Data Portal

# %%
import numpy as np
import pandas as pd
from pyopendatato.ckanTO import ckanTO as ckanTO

# %%
ct = ckanTO()
ct.search_packages(query = "subway")
# Out:
#                                      id  \
# 0  4eb6a6af-7199-4822-a89e-3e3ce5106d14
# 1  996cfe8d-fb35-40ce-b569-698d51fc683b
# 2  c01c6d71-de1f-493d-91ba-364ce64884ac
#
#                                                title          topics  \
# 0  TTC Ridership - Subway-Scarborough RT Station ...  Transportation
# 1                              TTC Subway Delay Data  Transportation
# 2                              TTC Subway Shapefiles            None
#
#                                              excerpt formats  num_resources  \
# 0  This dataset lists typical subway station/SRT ...    XLSX              5
# 1                              TTC Subway Delay Data    XLSX             32
# 2  This dataset contains separate shape files for...     SHP              1
#
#    refresh_rate last_refreshed  \
# 0      Annually
# 1       Monthly
# 2  As available
#
#                                                notes
# 0    \r\n  \r\nThis dataset lists typical subway ...
# 1  TTC Subway & SRT Train Service Delay Data\r\n\r\n
# 2  \r\nThis dataset contains separate shape files...

# %%
ct.get_package_metadata("996cfe8d-fb35-40ce-b569-698d51fc683b")
# Out:
# {'id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#  'title': 'TTC Subway Delay Data',
#  'topics': 'Transportation',
#  'excerpt': 'TTC Subway Delay Data',
#  'formats': 'XLSX',
#  'num_resources': 32,
#  'refresh_rate': 'Monthly',
#  'last_refreshed': '',
#  'notes': 'TTC Subway & SRT Train Service Delay Data\r\n\r\n',
#  'resources': [{'id': 'fece136b-224a-412a-b191-8d31eb00491e',
#    'name': 'ttc-subway-delay-codes',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:10.332408',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/fece136b-224a-412a-b191-8d31eb00491e/download/ttc-subway-delay-codes.xlsx'},
#   {'id': '6664420f-316f-4f94-9ba4-d4b4677aeea9',
#    'name': 'ttc-subway-delay-jan-2014-april-2017',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:15.670145',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/6664420f-316f-4f94-9ba4-d4b4677aeea9/download/ttc-subway-delay-jan-2014-april-2017.xlsx'},
#   {'id': 'd1159888-0035-45a0-b238-86b546555ac0',
#    'name': 'ttc-subway-delay-may-2017',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:17.302699',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/d1159888-0035-45a0-b238-86b546555ac0/download/ttc-subway-delay-may-2017.xlsx'},
#   {'id': '240d8e8c-d300-4f91-b94f-cbb3d136d25e',
#    'name': 'ttc-subway-delay-june-2017',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:19.042255',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/240d8e8c-d300-4f91-b94f-cbb3d136d25e/download/ttc-subway-delay-june-2017.xlsx'},
#   {'id': '98d4ac77-aa9f-40a3-97ee-6fc9070da252',
#    'name': 'ttc-subway-delay-july-2017',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:20.927993',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/98d4ac77-aa9f-40a3-97ee-6fc9070da252/download/ttc-subway-delay-july-2017.xlsx'},
#   {'id': '92e7649a-cf2f-4ac7-9802-b7f92f00b384',
#    'name': 'ttc-subway-delay-august-2017',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:22.561192',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/92e7649a-cf2f-4ac7-9802-b7f92f00b384/download/ttc-subway-delay-august-2017.xlsx'},
#   {'id': '61412f10-656b-4992-9a1a-a156dcf2f6c7',
#    'name': 'ttc-subway-delay-september-2017',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:24.249581',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource
2018',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:48.783548',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/5e3067a3-ff0a-4ecf-a25b-5cf59e7adc25/download/ttc-subway-delay-november-2018.xlsx'},
#   {'id': 'b4e5c8d0-36b3-4e24-8f24-30bf59fded2d',
#    'name': 'ttc-subway-delay-december-2018',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:50.409537',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/b4e5c8d0-36b3-4e24-8f24-30bf59fded2d/download/ttc-subway-delay-december-2018.xlsx'},
#   {'id': '54247e39-5a7d-40db-a137-82b2a9ab0708',
#    'name': 'ttc-subway-delay-readme',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:08.691341',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/54247e39-5a7d-40db-a137-82b2a9ab0708/download/ttc-subway-delay-readme.xlsx'},
#   {'id': '9a824dba-20cc-40b1-8f26-778a34a0f3a8',
#    'name': 'ttc-subway-delay-january-2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:52.085854',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/9a824dba-20cc-40b1-8f26-778a34a0f3a8/download/ttc-subway-delay-january-2019.xlsx'},
#   {'id': 'e6bac74e-2da2-4429-a76f-202eba3d9193',
#    'name': 'ttc-subway-delay-february-2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:53.935977',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/e6bac74e-2da2-4429-a76f-202eba3d9193/download/ttc-subway-delay-february-2019.xlsx'},
#   {'id': '0511879f-3233-4a42-8c28-93b432132c8b',
#    'name': 'ttc-subway-delay-march-2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:55.592208',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/0511879f-3233-4a42-8c28-93b432132c8b/download/ttc-subway-delay-march-2019.xlsx'},
#   {'id': '447b4a5a-f696-4f05-86c0-9602f56922e5',
#    'name': 'ttc-subway-delay-april-2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:57.206162',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/447b4a5a-f696-4f05-86c0-9602f56922e5/download/ttc-subway-delay-april-2019.xlsx'},
#   {'id': 'a302fcab-81a1-4142-b0ec-031b0666c1df',
#    'name': 'ttc-subway-delay-may-2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:25:58.885724',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/a302fcab-81a1-4142-b0ec-031b0666c1df/download/ttc-subway-delay-may-2019.xlsx'},
#   {'id': '655a138c-d381-4fe7-b3b3-a6620825161f',
#    'name': 'ttc-subway-delay-june-2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-08-15T16:26:00.967414',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/655a138c-d381-4fe7-b3b3-a6620825161f/download/ttc-subway-delay-june-2019.xlsx'},
#   {'id': '34d9619f-0239-4dad-a598-b6bc71ce1071',
#    'name': 'ttc-subway-delay-July 2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-10-07T18:19:38.444223',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/34d9619f-0239-4dad-a598-b6bc71ce1071/download/subway-srt-logs-july-2019.xlsx'},
#   {'id': 'b6557580-a0f4-4c96-9ce2-82657b62e88a',
#    'name': 'ttc-subway-delay-August-2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-10-07T18:22:25.050270',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/b6557580-a0f4-4c96-9ce2-82657b62e88a/download/subway-srt-logs-august-2019.xlsx'},
#   {'id': 'e2a5e386-ddf7-4416-8e84-c3508c4f9a4f',
#    'name': 'ttc-subway-delay-September 2019',
#    'format': 'XLSX',
#    'datastore_active': False,
#    'last_modified': '2019-10-07T18:23:49.097456',
#    'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b',
#    'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/e2a5e386-ddf7-4416-8e84-c3508c4f9a4f/download/subway-srt-logs-september-2019.xlsx'}]}

# %%
data_list = ct.get_package_metadata("996cfe8d-fb35-40ce-b569-698d51fc683b")['resources']

df = pd.DataFrame()
for data in data_list:
    if data["name"] != "ttc-subway-delay-codes":
        df = df.append(ct.get_resource(data["id"]))

df.reset_index(drop = True, inplace = True)

# %%
for data in data_list:
    if data["name"] == "ttc-subway-delay-codes":
        mapping = ct.get_resource(data["id"])

# %%
mapping = mapping.drop(columns = ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 4', 'Unnamed: 5'], index = 0)
mapping.columns = ['code_sub', 'desc_sub', 'code_srt', 'desc_srt']
mapping
# Out:
#     code_sub                                    desc_sub code_srt  \
# 1       EUAC                            Air Conditioning     ERAC
# 2       EUAL                         Alternating Current     ERBO
# 3      EUATC                          ATC RC&S Equipment     ERCD
# 4       EUBK                                      Brakes     ERCO
# 5       EUBO                                        Body     ERDB
# 6       EUCA                              Compressed Air     ERDO
# 7       EUCD  Consequential Delay (2nd Delay Same Fault)     ERHV
# 8       EUCH                             Chopper Control     ERLT
# 9       EUCO                                    Couplers     ERLV
# 10      EUDO            Door Problems - Faulty Equipment     ERME
# 11     EUECD           ECD / Line Mechanic Related Prob.    ERNEA
# 12      EUHV                                High Voltage     ERNT
# 13      EULT                             Lighting System      ERO
# 14      EULV                                 Low Voltage     ERPR
# 15      EUME            RC&S Maintenance Error - (Human)     ERRA
# 16     EUNEA                      No Equipment Available     ERTB
# 17      EUNT                Equipment - No Trouble Found     ERTC
# 18       EUO                                  RC&S Other     ERTL
# 19      EUOE                Rail Cars & Shops Opr. Error     ERTR
# 20     EUOPO         OPTO RC&S Non-Train Door Monitoring     ERVE
# 21      EUPI                           Propulsion System     ERWA
# 22      EUSC                   Speed Control Equipment       ERWS
# 23      EUTL                            Trainline System     MRCL
# 24      EUTM                             Traction Motors      MRD
# 25      EUTR                                      Trucks     MRDD
# 26     EUTRD                                TR Cab Doors     MREC
# 27      EUVA                       Warning Alarm Systems    MRESA
# 28      EUVE                                Work Vehicle     MRFS
# 29     EUYRD              Yard/Carhouse Related Problems     MRIE
# 30     MUATC                                 ATC Project     MRLD
# ..       ...                                         ...      ...
# 100    PUTWZ                  Work Zone Problems - Track      NaN
# 101     SUAE                 Assault / Employee Involved      NaN
# 102     SUAP                   Assault / Patron Involved      NaN
# 103     SUBT                                 Bomb Threat      NaN
# 104    SUCOL             Collector Booth Alarm Activated      NaN
# 105     SUDP                           Disorderly Patron      NaN
# 106    SUEAS          Emergency Alarm Station Activation      NaN
# 107      SUG                       Graffiti / Scratchiti      NaN
# 108      SUO                             Passenger Other      NaN
# 109    SUPOL             Held By Polce - Non-TTC Related      NaN
# 110    SUROB                                     Robbery      NaN
# 111     SUSA                              Sexual Assault      NaN
# 112     SUSP                          Suspicious Package      NaN
# 113     SUUT                 Unauthorized at Track Level      NaN
# 114    TUATC                        ATC Operator Related      NaN
# 115     TUCC            Transit Control Related Problems      NaN
# 116    TUDOE                         Doors Open in Error      NaN
# 117    TUKEY              Two Drum Switch Keys Activated      NaN
# 118     TUML                            Mainline Storage      NaN
# 119    TUMVS                    Operator Violated Signal      NaN
# 120    TUNIP                    Operator Not In Position      NaN
# 121    TUNOA          No Operator Immediately Available       NaN
# 122      TUO           Transportation Department - Other      NaN
# 123    TUOPO                       OPTO Operator Related      NaN
# 124     TUOS                  Operator Overshot Platform      NaN
# 125      TUS            Crew Unable to Maintain Schedule      NaN
# 126     TUSC                       Operator Overspeeding      NaN
# 127    TUSET         Train Controls Improperly Shut Down      NaN
# 128     TUST                                Storm Trains      NaN
# 129    TUSUP                           Supervisory Error      NaN
#
#                                               desc_srt
# 1                                     Air Conditioning
# 2                                                 Body
# 3           Consequential Delay (2nd Delay Same Fault)
# 4                                             Couplers
# 5                                          Disc Brakes
# 6                     Door Problems - Faulty Equipment
# 7                                         High Voltage
# 8                                      Lighting System
# 9                                          Low Voltage
# 10                    RC&S Maintenance Error - (Human)
# 11                              No Equipment Available
# 12                        Equipment - No Trouble Found
# 13                                          RC&S Other
# 14                                   Propulsion System
# 15                                               Radio
# 16                                        Track Brakes
# 17                                Train Control - VOBC
# 18                                    Trainline System
# 19                                              Trucks
# 20                                             Vehicle
# 21                               Warning Alarm Systems
# 22                                         Wind Shield
# 23                            Divisional Clerk Related
# 24                   Door Problems - Passenger Related
# 25                      Door Problems - Debris Related
# 26   Misc. Engineering & Construction Related Problems
# 27                   No Operator Immediately Available
# 28          Fire/Smoke Plan B - Source External to TTC
# 29                                    Injured Employee
# 30                             Labour Dispute - Subway
# ..                                                 ...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
#
# [129 rows x 4 columns]

# %%
mapping = pd.concat([mapping[['code_sub', 'desc_sub']].rename(columns = {'code_sub': 'Code', 'desc_sub': 'Desc'}), 
                     mapping[['code_srt', 'desc_srt']].rename(columns = {'code_srt': 'Code', 'desc_srt': 'Desc'})])

mapping = mapping.dropna().reset_index(drop = True)
mapping
# Out:
#       Code                                               Desc
# 0     EUAC                                   Air Conditioning
# 1     EUAL                                Alternating Current
# 2    EUATC                                 ATC RC&S Equipment
# 3     EUBK                                             Brakes
# 4     EUBO                                               Body
# 5     EUCA                                     Compressed Air
# 6     EUCD         Consequential Delay (2nd Delay Same Fault)
# 7     EUCH                                    Chopper Control
# 8     EUCO                                           Couplers
# 9     EUDO                   Door Problems - Faulty Equipment
# 10   EUECD                  ECD / Line Mechanic Related Prob.
# 11    EUHV                                       High Voltage
# 12    EULT                                    Lighting System
# 13    EULV                                        Low Voltage
# 14    EUME                   RC&S Maintenance Error - (Human)
# 15   EUNEA                             No Equipment Available
# 16    EUNT                       Equipment - No Trouble Found
# 17     EUO                                         RC&S Other
# 18    EUOE                       Rail Cars & Shops Opr. Error
# 19   EUOPO                OPTO RC&S Non-Train Door Monitoring
# 20    EUPI                                  Propulsion System
# 21    EUSC                          Speed Control Equipment
# 22    EUTL                                   Trainline System
# 23    EUTM                                    Traction Motors
# 24    EUTR                                             Trucks
# 25   EUTRD                                       TR Cab Doors
# 26    EUVA                              Warning Alarm Systems
# 27    EUVE                                       Work Vehicle
# 28   EUYRD                     Yard/Carhouse Related Problems
# 29   MUATC                                        ATC Project
# ..     ...                                                ...
# 170  MRUIR  Injured or ill Customer (On Train) - Medical A...
# 171  MRWEA                   Weather Reports / Related Delays
# 172   PREL                        Escalator/Elevator Incident
# 173    PRO                                              Other
# 174    PRS                                       VCC/RCIU/CCR
# 175   PRSA                               Axle Counter Related
# 176   PRSL                              Loop Related Failures
# 177   PRSO                                      Signals Other
# 178   PRSP                       Signals Power Supply Related
# 179   PRST                         Station Stairway Incident
# 180   PRSW                                     Switch Related
# 181  PRTST                              Signals - Train Stops
# 182    PRW                  Rail Defect/Fastenings/Power Rail
# 183   SRAE                        Assault / Employee Involved
# 184   SRAP                          Assault / Patron Involved
# 185   SRBT                                        Bomb Threat
# 186  SRCOL                    Collector Booth Alarm Activated
# 187   SRDP                                  Disorderly Patron
# 188  SREAS                 Emergency Alarm Station Activation
# 189    SRO                                    Passenger Other
# 190   SRSA                                     Sexual Assault
# 191   SRSP                                 Suspicious Package
# 192   SRUT                        Unauthorized at Track Level
# 193  TRDOE                                Doors Open in Error
# 194  TRNIP                           Operator Not In Position
# 195  TRNOA                 No Operator Immediately Available
# 196    TRO                  Transportation Department - Other
# 197  TRSET                Train Controls Improperly Shut Down
# 198   TRST                                       Storm Trains
# 199   TRTC                   Transit Control Related Problems
#
# [200 rows x 2 columns]

# %%
df = df.merge(mapping, on = 'Code', how = 'left')
df
# Out:
#        Bound   Code       Date        Day Description Example Field Name  \
# 0          W  MUPR1 2014-01-01  Wednesday         NaN     NaN        NaN
# 1          W   SUDP 2014-01-01  Wednesday         NaN     NaN        NaN
# 2        NaN  MUNCA 2014-01-01  Wednesday         NaN     NaN        NaN
# 3          W   SUDP 2014-01-01  Wednesday         NaN     NaN        NaN
# 4          S  MUSAN 2014-01-01  Wednesday         NaN     NaN        NaN
# 5          E  MUPAA 2014-01-01  Wednesday         NaN     NaN        NaN
# 6        NaN  MUNCA 2014-01-01  Wednesday         NaN     NaN        NaN
# 7        NaN  MUNCA 2014-01-01  Wednesday         NaN     NaN        NaN
# 8        NaN  MUNCA 2014-01-01  Wednesday         NaN     NaN        NaN
# 9        NaN  MUNCA 2014-01-01  Wednesday         NaN     NaN        NaN
# 10       NaN  MUNCA 2014-01-01  Wednesday         NaN     NaN        NaN
# 11       NaN  MUNCA 2014-01-01  Wednesday         NaN     NaN        NaN
# 12         E  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 13         E  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 14         S   TUSC 2014-01-01  Wednesday         NaN     NaN        NaN
# 15         E  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 16         W  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 17         W  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 18         W  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 19         S  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 20       NaN    SUG 2014-01-01  Wednesday         NaN     NaN        NaN
# 21         S  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 22         S  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 23         S  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 24         E   SUDP 2014-01-01  Wednesday         NaN     NaN        NaN
# 25         S  MUNOA 2014-01-01  Wednesday         NaN     NaN        NaN
# 26         W   MUTO 2014-01-01  Wednesday         NaN     NaN        NaN
# 27         N   MUSC 2014-01-01  Wednesday         NaN     NaN        NaN
# 28         S  SUEAS 2014-01-01  Wednesday         NaN     NaN        NaN
# 29         W   MUIR 2014-01-01  Wednesday         NaN     NaN        NaN
# ...      ...    ...        ...        ...         ...     ...        ...
# 117350     E    MUD 2019-09-30     Monday         NaN     NaN        NaN
# 117351     N    MUI 2019-09-30     Monday         NaN     NaN        NaN
# 117352     S    TUO 2019-09-30     Monday         NaN     NaN        NaN
# 117353   NaN   MUTO 2019-09-30     Monday         NaN     NaN        NaN
# 117354     E    SUO 2019-09-30     Monday         NaN     NaN        NaN
# 117355   NaN   MUIS 2019-09-30     Monday         NaN     NaN        NaN
# 117356     E    EUO 2019-09-30     Monday         NaN     NaN        NaN
# 117357   NaN   MUIS 2019-09-30     Monday         NaN     NaN        NaN
# 117358   NaN   MUIS 2019-09-30     Monday         NaN     NaN        NaN
# 117359     E  MUNOA 2019-09-30     Monday         NaN     NaN        NaN
# 117360     W   SUUT 2019-09-30     Monday         NaN     NaN        NaN
# 117361     E   TUSC 2019-09-30     Monday         NaN     NaN        NaN
# 117362   NaN   MUIS 2019-09-30     Monday         NaN     NaN        NaN
# 117363     E   EUSC 2019-09-30     Monday         NaN     NaN        NaN
# 117364     N   MUSC 2019-09-30     Monday         NaN     NaN        NaN
# 117365     S   MUSC 2019-09-30     Monday         NaN     NaN        NaN
# 117366     W   TUSC 2019-09-30     Monday         NaN     NaN        NaN
# 117367     E  MUPAA 2019-09-30     Monday         NaN     NaN        NaN
# 117368     S    MUO 2019-09-30     Monday         NaN     NaN        NaN
# 117369     E   TUSC 2019-09-30     Monday         NaN     NaN        NaN
# 117370     N   MUIR 2019-09-30     Monday         NaN     NaN        NaN
# 117371     S   SUDP 2019-09-30     Monday         NaN     NaN        NaN
# 117372     E  TUMVS 2019-09-30     Monday         NaN     NaN        NaN
# 117373     S    MUI 2019-09-30     Monday         NaN     NaN        NaN
# 117374   NaN    MUO 2019-09-30     Monday         NaN     NaN        NaN
# 117375     E   TUSC 2019-09-30     Monday         NaN     NaN        NaN
# 117376     W  SUEAS 2019-09-30     Monday         NaN     NaN        NaN
# 117377   NaN   SUAP 2019-09-30     Monday         NaN     NaN        NaN
# 117378   NaN    MUO 2019-09-30     Monday         NaN     NaN        NaN
# 117379     S   MUTO 2019-09-30     Monday         NaN     NaN        NaN
#
#          Line  Min Delay  Min Gap                 Station   Time  Vehicle  \
# 0          BD       55.0     60.0   VICTORIA PARK STATION  00:21   5111.0
# 1          BD        3.0      7.0       HIGH PARK STATION  02:06   5001.0
# 2          YU        0.0      0.0        SHEPPARD STATION  02:40      0.0
# 3          BD        3.0      8.0       LANSDOWNE STATION  03:10   5116.0
# 4          YU        5.0     10.0           BLOOR STATION  03:20   5386.0
# 5          BD        0.0      0.0        DUFFERIN STATION  03:29   5174.0
# 117370     YU        4.0      6.0   SHEPPARD WEST STATION  18:02   5996.0
# 117371     YU        3.0      6.0           FINCH STATION  20:50   5411.0
# 117372     BD        0.0      0.0             BAY STATION  20:58   5274.0
# 117373     YU       19.0     23.0      YORK MILLS STATION  21:44   5701.0
# 117374  YU/BD        0.0      0.0  YONGE-UNIVERSITY AND B  22:00      0.0
# 117375     BD        0.0      0.0       GREENWOOD STATION  22:04   5332.0
# 117376     BD       16.0     20.0    KEELE TO DUNDAS WEST  22:30   5105.0
# 117377     BD        0.0      0.0      ROYAL YORK STATION  22:34      0.0
# 117378     BD        0.0      0.0   BLOOR DANFORTH SUBWAY  23:00      0.0
# 117379     YU        3.0      8.0          WILSON STATION  23:25   5696.0
#
#                                                      Desc
# 0             Priority One - Train in Contact With Person
# 1                                       Disorderly Patron
# 2                                                     NaN
# 3                                       Disorderly Patron
# 4                                      Unsanitary Vehicle
# 5       Passenger Assistance Alarm Activated - No Trou...
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12      No Operator Immediately Available - Not E.S.A....
# 13      No Operator Immediately Available - Not E.S.A....
# 14                                  Operator Overspeeding
# 15      No Operator Immediately Available - Not E.S.A....
# 16      No Operator Immediately Available - Not E.S.A....
# 17      No Operator Immediately Available - Not E.S.A....
# 18      No Operator Immediately Available - Not E.S.A....
# 19      No Operator Immediately Available - Not E.S.A....
# 20                                  Graffiti / Scratchiti
# 21      No Operator Immediately Available - Not E.S.A....
# 22      No Operator Immediately Available - Not E.S.A....
# 23      No Operator Immediately Available - Not E.S.A....
# 24                                      Disorderly Patron
# 25      No Operator Immediately Available - Not E.S.A....
# 26      Misc. Transportation Other - Employee Non-Char...
# 27                            Miscellaneous Speed Control
# 28                     Emergency Alarm Station Activation
# 29      Injured or ill Customer (On Train) - Medical A...
# ...                                                   ...
# 117350                  Door Problems - Passenger Related
# 117351   Injured or ill Customer (On Train) - Transported
# 117352                  Transportation Department - Other
# 117353  Misc. Transportation Other - Employee Non-Char...
# 117354                                    Passenger Other
# 117355  Injured or ill Customer (In Station) - Transpo...
# 117356                                         RC&S Other
# 117357  Injured or ill Customer (In Station) - Transpo...
# 117358  Injured or ill Customer (In Station) - Transpo...
# 117359  No Operator Immediately Available - Not E.S.A....
# 117360                        Unauthorized at Track Level
# 117361                              Operator Overspeeding
# 117362  Injured or ill Customer (In Station) - Transpo...
# 117363                          Speed Control Equipment
# 117364                        Miscellaneous Speed Control
# 117365                        Miscellaneous Speed Control
# 117366                              Operator Overspeeding
# 117367  Passenger Assistance Alarm Activated - No Trou...
# 117368                                Miscellaneous Other
# 117369                              Operator Overspeeding
# 117370  Injured or ill Customer (On Train) - Medical A...
# 117371                                  Disorderly Patron
# 117372                           Operator Violated Signal
# 117373   Injured or ill Customer (On Train) - Transported
# 117374                                Miscellaneous Other
# 117375                              Operator Overspeeding
# 117376                 Emergency Alarm Station Activation
# 117377                          Assault / Patron Involved
# 117378                                Miscellaneous Other
# 117379  Misc. Transportation Other - Employee Non-Char...
#
# [117380 rows x 14 columns]

# %% [markdown]
# ### Exploratory Data Analysis
#
# - data missingness/strange values
# - what info is available/useful
